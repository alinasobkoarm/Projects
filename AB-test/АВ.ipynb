# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет Алина !</b>
#
# Меня зовут Дмитрий Михаленко, я буду ревьюером твоего проекта. Если ты не против, то предлагаю построить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# Ниже в работе ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**.
#
# Для наглядности я буду использовать цветовую разметку:
# <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге может стать еще лучше, если внести небольшие коррективы.
# Но настаивать я не буду.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Для правильного решения задачи на этом шаге необходимо внести правки. Напоминаю, что проект не может быть принят, без их отработки.
# </div>
#
# Для продуктивной работы прошу: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом**
# Мне будет легче отследить изменения, если ты тоже выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
# Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# # Часть 1. Проверка гипотезы в Python и составление аналитической записки

# %% [markdown]
# Вы предобработали данные в SQL, и теперь они готовы для проверки гипотезы в Python. Загрузите данные пользователей из Москвы и Санкт-Петербурга c суммой часов их активности из файла yandex_knigi_data.csv. Если работаете локально, скачать файл можно по ссылке.
#
# Проверьте наличие дубликатов в идентификаторах пользователей. Сравните размеры групп, их статистики и распределение.
#
# Напомним, как выглядит гипотеза: пользователи из Санкт-Петербурга проводят в среднем больше времени за чтением и прослушиванием книг в приложении, чем пользователи из Москвы. Попробуйте статистически это доказать, используя одностороннюю проверку гипотезы с двумя выборками:
#
# Нулевая гипотеза $H_0: \mu_{\text{СПб}} \leq \mu_{\text{Москва}}$ <br> Среднее время активности пользователей в Санкт-Петербурге не больше, чем в Москве.
#
# Альтернативная гипотеза $H_1: \mu_{\text{СПб}} > \mu_{\text{Москва}}$ <br> Среднее время активности пользователей в Санкт-Петербурге больше, и это различие статистически значимо.
#
# По результатам анализа данных подготовьте аналитическую записку, в которой опишите:
#
# Выбранный тип t-теста и уровень статистической значимости.
#
# Результат теста, или p-value.
#
# Вывод на основе полученного p-value, то есть интерпретацию результатов.
#
# Одну или две возможные причины, объясняющие полученные результаты.

# %% [markdown]
# ## Напишите заголовок первой части проекта здесь
#
# - Автор: Собко Алина Сергеевна
# - Дата: 05.07.2026

# %% [markdown]
# ## Цели и задачи проекта
#
# <font color='#777778'>Задачей проекта является проверка гипотезы о том, что жители Санкт-Петербурга более активно используют приложение "Яндекс.Книги". Целями проекты являются выгрузка и предобработка данных, в том числе проверка дубликатов в идентификаторах пользователей, сравнение групп, их статистики, выбор статистического теста, проведение теста, описание полученных результатов.</font>

# %% [markdown]
# ## Описание данных
#
# <font color='#777778'>Таблица данных состоит из следующих полей:
# city — город пользователя;
# puid — идентификатор пользователя;
# hours — общее количество часов активности (вычисляется по полю hours).</font>

# %% [markdown]
# ## Содержимое проекта
#
# <font color='#777778'><br>1. Загрузка данные пользователей из Москвы и Санкт-Петербурга c суммой часов их активности из файла yandex_knigi_data.csv. <br>2. Проверка наличия дубликатов в идентификаторах пользователей, удаление дубликатов. <br>3. Сравнение размеров групп, их статистики и распределения, построение необходимых графиков.<br>4. Формулировка гипотезы. <br>5. Подготовка аналитической записки по результатам проведенного теста</font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Качественное  введение в проект! Есть все, чтобы твой будущий работодатель знал все ключевые моменты проекта и мог объективно оценить принимаемые тобой решения.

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
import seaborn as sns
from statsmodels.stats.power import NormalIndPower
from statsmodels.stats.proportion import proportion_effectsize
from math import ceil
from statsmodels.stats.proportion import proportions_ztest
df = pd.read_csv('/datasets/yandex_knigi_data.csv')
display (df)
# Out:
#       Unnamed: 0             city              puid       hours
# 0              0           Москва              9668   26.167776
# 1              1           Москва             16598   82.111217
# 2              2           Москва             80401    4.656906
# 3              3           Москва            140205    1.840556
# 4              4           Москва            248755  151.326434
# ...          ...              ...               ...         ...
# 8779        8779  Санкт-Петербург  1130000028554332    4.107774
# 8780        8780  Санкт-Петербург  1130000030307246   45.069222
# 8781        8781  Санкт-Петербург  1130000038726322    0.211944
# 8782        8782  Санкт-Петербург  1130000047892100    4.311841
# 8783        8783  Санкт-Петербург  1130000061443598   20.847222
#
# [8784 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Добавлю, что столбец без названия не несет полезной функции для нас и его можно удалить, чтобы не занимать лишее место в памяти

# %%
df = df.drop('Unnamed: 0',axis=1)
display(df)
# Out:
#                  city              puid       hours
# 0              Москва              9668   26.167776
# 1              Москва             16598   82.111217
# 2              Москва             80401    4.656906
# 3              Москва            140205    1.840556
# 4              Москва            248755  151.326434
# ...               ...               ...         ...
# 8779  Санкт-Петербург  1130000028554332    4.107774
# 8780  Санкт-Петербург  1130000030307246   45.069222
# 8781  Санкт-Петербург  1130000038726322    0.211944
# 8782  Санкт-Петербург  1130000047892100    4.311841
# 8783  Санкт-Петербург  1130000061443598   20.847222
#
# [8784 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Удален столбец без названия.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> практичное решение

# %%
print (len(df))
print (df['puid'].nunique())
# Out:
# 8784
# 8540

# %%
df_clean = df.drop_duplicates(subset=['puid'], keep='first')
display (df)
# Out:
#                  city              puid       hours
# 0              Москва              9668   26.167776
# 1              Москва             16598   82.111217
# 2              Москва             80401    4.656906
# 3              Москва            140205    1.840556
# 4              Москва            248755  151.326434
# ...               ...               ...         ...
# 8779  Санкт-Петербург  1130000028554332    4.107774
# 8780  Санкт-Петербург  1130000030307246   45.069222
# 8781  Санкт-Петербург  1130000038726322    0.211944
# 8782  Санкт-Петербург  1130000047892100    4.311841
# 8783  Санкт-Петербург  1130000061443598   20.847222
#
# [8784 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Полезная проверка на дубликаты. Для `ttest` в дальнейшем понадобятся независимые выборки и они стали таковыми

# %%
print(df[df['city'] == 'Москва'].describe())
print(df[df['city'] == 'Санкт-Петербург'].describe())
# Out:
#                puid        hours
# count  6.234000e+03  6234.000000
# mean   1.123926e+13    10.881092
# std    1.121386e+14    36.851683
# min    9.668000e+03     0.000018
# 25%    3.139885e+08     0.059903
# 50%    8.730945e+08     0.924498
# 75%    1.510930e+09     5.939972
# max    1.130000e+15   857.209373
#                puid        hours
# count  2.550000e+03  2550.000000
# mean   7.977401e+12    11.592691
# std    9.462180e+13    39.704993
# min    1.049230e+05     0.000025
# 25%    3.442209e+08     0.080002
# 50%    9.133665e+08     0.984781
# 75%    1.530662e+09     6.509072
# max    1.130000e+15   978.764775

# %%
plt.figure(figsize=(10, 7))
sns.histplot(data=df[df['city'] == 'Санкт-Петербург'], 
             x='order', 
             kde=True, 
             color='green', 
             bins=50)
plt.title('Распределение активности: Санкт-Петербург', fontsize=14)
plt.xlabel('Активность (часы)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.ylim(0, 2500) 
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(df[df['city'] == 'Санкт-Петербург']['hours'],
                 vert=False,
                 patch_artist=True,
                 showfliers=True,
                 widths=0.5)
plt.title('Распределение активности: Санкт-Петербург', fontsize=14)
plt.xlabel('Активность (часы)', fontsize=12)
plt.ylabel('', fontsize=12) 
plt.xlim(0, 80)
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.histplot(data=df[df['city'] == 'Москва'], 
             x='hours', 
             kde=True, 
             color='red', 
             bins=50)
plt.title('Распределение активности: Москва', fontsize=14)
plt.xlabel('Активность (часы)', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.ylim(0, 5500) 
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(df[df['city'] == 'Москва']['hours'],
                 vert=False,
                 patch_artist=True,
                 showfliers=True,
                 widths=0.5)
plt.title('Распределение активности: Москва', fontsize=14)
plt.xlabel('Активность (часы)', fontsize=12)
plt.ylabel('', fontsize=12) 
plt.xlim(0, 80)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>Тут можно сразу добавить обоснование типа теста на основе распределений

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> На основе представленных графиков распределения продолжительности использования приложением "Яндекс.Книги" жителями Санкт-Петербурга и Москвы выявлено, что в данных присутствуют выбросы и разброс данных довольно большой.
# <br> В связи с этим для проверки гипотезы о том, что пользователи из Санкт-Петербурга проводят в среднем больше времени за чтением и прослушиванием книг в приложении, чем пользователи из Москвы, использован тест Манна-Уитни.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> емко и логично

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Хотя на самом деле ненормальность распределения не мешает проводить `ttest` в силу ЦПТ. И если "почистить" выбросы, можно применить `ttest` с поправкой Уэлча, так как выборки отличны по размеру более чем на 25%. ОН будет иметь большую мощность, чем U-тест

# %% [markdown]
# ## 2. Проверка гипотезы в Python
#
# Гипотеза звучит так: пользователи из Санкт-Петербурга проводят в среднем больше времени за чтением и прослушиванием книг в приложении, чем пользователи из Москвы. Попробуйте статистически это доказать, используя одностороннюю проверку гипотезы с двумя выборками:
#
# - Нулевая гипотеза H₀: Средняя активность пользователей в часах в двух группах (Москва и Санкт-Петербург) не различается.
#
# - Альтернативная гипотеза H₁: Средняя активность пользователей в Санкт-Петербурге больше, и это различие статистически значимо.

# %%
moscow = df[df['city'] == 'Москва']['hours']
spb = df[df['city'] == 'Санкт-Петербург']['hours']
u_stat, p_value = mannwhitneyu(spb, moscow, alternative='greater')
alpha = 0.05
print(f"p-value: {p_value:.6f}")
if p_value < alpha:
    print("Нулевая гипотеза отвергнута. Средняя активность пользователей в Санкт-Петербурге больше, и это различие статистически значимо.")
else:
    print("Нет оснований отвергать нулевую гипотезу. Средняя активность пользователей в часах в двух группах (Москва и Санкт-Петербург) не различается.")
# Out:
# p-value: 0.089059
# Нет оснований отвергать нулевую гипотезу. Средняя активность пользователей в часах в двух группах (Москва и Санкт-Петербург) не различается.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Сам тест проведен корректно и настроен удобный автоматический вывод результатов

# %% [markdown]
# ## 3. Аналитическая записка
# По результатам анализа данных подготовьте аналитическую записку, в которой опишете:
#
# - Выбранный тип t-теста и уровень статистической значимости.
#
# - Результат теста, или p-value.
#
# - Вывод на основе полученного p-value, то есть интерпретацию результатов.
#
# - Одну или две возможные причины, объясняющие полученные результаты.

# %% [markdown]
# На основании исследования графиков распределения продолжительности использования приложением "Яндекс.Книги" жителями Санкт-Петербурга и Москвы выявлено, что в данных присутствуют выбросы и разброс данных довольно большой.
# <br> В связи с этим для проверки гипотезы о том, что пользователи из Санкт-Петербурга проводят в среднем больше времени за чтением и прослушиванием книг в приложении, чем пользователи из Москвы, использован тест Манна-Уитни.
# <br> p-value равен 0.089, что превышает уровень статистической значимости, составляющий 0.05.
# Это свидетельствует о том, что нет оснований отвергать нулевую гипотезу. Средняя активность пользователей в часах в двух группах (Москва и Санкт-Петербург) не различается.
# <br>Причины:
# <br>1.Разница средних в двух группах составила 11.59-10.88 = 0.71 (часа), что может быть случайной величиной.
# <br>2.Большой разброс значений внутри групп на фоне маленькой разницы средних.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>Добавлю, что у жителей этих городов схожий образ жизни и бытовые привычки и это помогает логично объяснить результаты

# %% [markdown]
# ----

# %% [markdown]
# # Часть 2. Анализ результатов A/B-тестирования

# %% [markdown]
# Теперь вам нужно проанализировать другие данные. Представьте, что к вам обратились представители интернет-магазина BitMotion Kit, в котором продаются геймифицированные товары для тех, кто ведёт здоровый образ жизни. У него есть своя целевая аудитория, даже появились хиты продаж: эспандер со счётчиком и напоминанием, так и подстольный велотренажёр с Bluetooth.
#
# В будущем компания хочет расширить ассортимент товаров. Но перед этим нужно решить одну проблему. Интерфейс онлайн-магазина слишком сложен для пользователей — об этом говорят отзывы.
#
# Чтобы привлечь новых клиентов и увеличить число продаж, владельцы магазина разработали новую версию сайта и протестировали его на части пользователей. По задумке, это решение доказуемо повысит количество пользователей, которые совершат покупку.
#
# Ваша задача — провести оценку результатов A/B-теста. В вашем распоряжении:
#
# * данные о действиях пользователей и распределении их на группы,
#
# * техническое задание.
#
# Оцените корректность проведения теста и проанализируйте его результаты.

# %% [markdown]
# ## 1. Опишите цели исследования.

# %% [markdown]
# Цели исследования: выделить пользователей, участвующих в тесте interface_eu_test, и проверить соответствие требованиям технического задания, равномерность распределения пользователей по группам теста, отсутствие пересечений с конкурирующим тестом (нет пользователей, участвующих одновременно в двух тестовых группах); проанализировать данные о пользовательской активност: оставить только события, связанные с участвующими в изучаемом тесте пользователями, рассчитать время совершения события пользователем после регистрации и оставить только те события, которые были выполнены в течение первых семи дней с момента регистрации; оценить достаточность выборки для получения статистически значимых результатов A/B-теста; рассчитать конверсию в покупку пользователей групп А и В; оценить изменение конверсии подходящим статистическим тестом, учитывая все этапы проверки гипотез.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Контекст задачи описан, посмотрим как ее лучше всего решать

# %% [markdown]
# ## 2. Загрузите данные, оцените их целостность.

# %%
participants = pd.read_csv('https://code.s3.yandex.net/datasets/ab_test_participants.csv')
events = pd.read_csv('https://code.s3.yandex.net/datasets/ab_test_events.zip',
                     parse_dates=['event_dt'], low_memory=False)
display(participants)
display(events)
# Out:
#                 user_id group                  ab_test   device
# 0      0002CE61FF2C4011     B        interface_eu_test      Mac
# 1      001064FEAAB631A1     B  recommender_system_test  Android
# 2      001064FEAAB631A1     A        interface_eu_test  Android
# 3      0010A1C096941592     A  recommender_system_test  Android
# 4      001E72F50D1C48FA     A        interface_eu_test      Mac
# ...                 ...   ...                      ...      ...
# 14520  FFE7FC140521F5F6     A        interface_eu_test       PC
# 14521  FFEFC0E55C1CCD4F     A        interface_eu_test       PC
# 14522  FFF28D02B1EACBE1     B  recommender_system_test       PC
# 14523  FFF28D02B1EACBE1     B        interface_eu_test       PC
# 14524  FFF58BC33966EB51     A        interface_eu_test  Android
#
# [14525 rows x 4 columns]
#                  user_id            event_dt  \
# 0                 GLOBAL 2020-12-01 00:00:00
# 1       CCBE9E7E99F94A08 2020-12-01 00:00:11
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Данные успешно загружены и ты взглянула на них. Но нет никакого вывода по этапу предварительного обзора. Есть ли пропуски и помешают ли они? Что будем делать со "странными" строками с `GLOBAL`?....

# %%
print(participants.isnull().sum())
print(events.isnull().sum())
# Out:
# user_id    0
# group      0
# ab_test    0
# device     0
# dtype: int64
# user_id            0
# event_dt           0
# event_name         0
# details       538264
# dtype: int64

# %%
events = events[events['user_id'] != 'GLOBAL'].copy()
display(events)
# Out:
#                  user_id            event_dt    event_name details
# 1       CCBE9E7E99F94A08 2020-12-01 00:00:11  registration     0.0
# 3       CCBE9E7E99F94A08 2020-12-01 00:00:33         login     NaN
# 4       CCBE9E7E99F94A08 2020-12-01 00:00:52  product_page     NaN
# 5       AA346F4D22148024 2020-12-01 00:01:46  registration    -2.0
# 6       7EF01D0E72AF449D 2020-12-01 00:02:06  registration    -5.0
# ...                  ...                 ...           ...     ...
# 787280  10CAFD77114A4537 2020-12-31 23:57:35  product_page     NaN
# 787281  1A655C280B064708 2020-12-31 23:57:44  product_page     NaN
# 787282  B77B2F4BCA134618 2020-12-31 23:58:23  registration     0.0
# 787284  B12AD1623E494FAD 2020-12-31 23:58:34  registration   -6.52
# 787285  5456977474344433 2020-12-31 23:59:48  registration   -3.67
#
# [728791 rows x 4 columns]

# %%
participants = participants.drop_duplicates(subset=['user_id'], keep='first')
events = events.drop_duplicates()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Пропуски присутствуют в столбце Details датафрейма с событиями, он не участвует в дальнейшем анализе, их можно оставить. Удалены строки, где User_id = 'GLOBAL'. Также удалены дубликаты до отбора нужного теста.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> учтено

# %% [markdown]
# ## 3. По таблице `ab_test_participants` оцените корректность проведения теста:
#
#    3\.1 Выделите пользователей, участвующих в тесте, и проверьте:
#
#    - соответствие требованиям технического задания,
#
#    - равномерность распределения пользователей по группам теста,
#
#    - отсутствие пересечений с конкурирующим тестом (нет пользователей, участвующих одновременно в двух тестовых группах).

# %%
#оставляем пользователей только нужного теста
participants_new = participants[participants['ab_test'] == 'interface_eu_test'].copy()

# %%
users_by_group = participants_new.groupby('group')['user_id'].nunique()
print(users_by_group)
# Out:
# group
# A    5174
# B    5229
# Name: user_id, dtype: int64

# %%
A = users_by_group['A']
B = users_by_group['B']
diff_of_percents = round(100 * abs(A - B) / A,2)
print(diff_of_percents)
# Out:
# 1.06

# %%
device_A = round(participants_new[participants_new['group'] == 'A'].groupby('user_id')['device'].first().value_counts(normalize=True) * 100,2)
device_B = round(participants_new[participants_new['group'] == 'B'].groupby('user_id')['device'].first().value_counts(normalize=True) * 100,2)
print(device_A)
print(device_B)
plt.figure(figsize=(12, 6))
colors = ['#4CAF50','#2196F3','#FF9800','#9C27B0']
device_A.plot(kind='bar',
                title='Распределение устройств в группе А',
                color=colors,
                legend=False,
                ylabel='Доля типа устройств',
                xlabel='Тип устройства',            
                figsize=(14, 8))
plt.grid(axis='y', alpha=0.3, linewidth=0.5, color='black')
plt.xticks(rotation=360)
plt.show()
# Out:
# Android    45.54
# PC         24.86
# iPhone     19.13
# Mac        10.48
# Name: device, dtype: float64
# Android    44.37
# PC         25.93
# iPhone     19.62
# Mac        10.08
# Name: device, dtype: float64

# %%
plt.figure(figsize=(12, 6))
colors = ['#4CAF50','#2196F3','#FF9800','#9C27B0']
device_B.plot(kind='bar',
                title='Распределение устройств в группе B',
                color=colors,
                legend=False,
                ylabel='Доля типа устройств',
                xlabel='Тип устройства',            
                figsize=(14, 8))
plt.grid(axis='y', alpha=0.3, linewidth=0.5, color='black')
plt.xticks(rotation=360)
plt.show()

# %%
group_A = participants_new[participants_new['group'] == 'A']['user_id']
group_B = participants_new[participants_new['group'] == 'B']['user_id']
intersection = list(set(group_A) & set(group_B))
print(intersection)
# Out:
# []

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Тут я не могу полностью согласиться с тобой, предварительно нужно проверить еще и пересечения между тестами до отбора интересующего нас, их лучше сразу удалить для большей объективности

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Удалены дубликаты до отбора пользователей нужного теста.</div>

# %% [markdown]
# 3\.2 Проанализируйте данные о пользовательской активности по таблице `ab_test_events`:
#
# - оставьте только события, связанные с участвующими в изучаемом тесте пользователями;

# %%
ab_test_events = events.merge(participants_new[['user_id']], on='user_id', how='inner')

# %% [markdown]
# - определите горизонт анализа: рассчитайте время (лайфтайм) совершения события пользователем после регистрации и оставьте только те события, которые были выполнены в течение первых семи дней с момента регистрации;

# %% [markdown]
# reg_dates = events[events['event_name'] == 'registration'][['user_id', 'event_dt']]
# reg_dates = reg_dates.rename(columns={'event_dt': 'reg_date'})
# events_7days = events.merge(reg_dates, on='user_id', how='inner')
# events_7days['days'] = (events_7days['event_dt'] - events_7days['reg_date']).dt.days
# events_7days = events_7days[(events_7days['days'] >= 0) & (events_7days['days'] <= 7)]

# %% [markdown]
# # Код ревьюера
# (events_7days.event_dt - events_7days.reg_date).max()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> давай перепроверим результаты,  в фильтрации есть ошибка

# %%
events['event_dt'] = pd.to_datetime(events['event_dt'])
reg_dates = events[events['event_name'] == 'registration'][['user_id', 'event_dt']]
reg_dates['reg_date'] = reg_dates['event_dt'].dt.date
events['event_date'] = events['event_dt'].dt.date
events_7days = events.merge(reg_dates, on='user_id', how='inner')
events_7days['days'] = (events_7days['event_date'] - events_7days['reg_date']).dt.days
events_7days = events_7days[(events_7days['days'] >= 0) & (events_7days['days'] <= 7)]

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Фильтрация изменена, события 8-го дня не попадают в фильтрацию.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Теперь строго первая неделя, молодец

# %% [markdown]
# Оцените достаточность выборки для получения статистически значимых результатов A/B-теста. Заданные параметры:
#
# - базовый показатель конверсии — 30%,
#
# - мощность теста — 80%,
#
# - достоверность теста — 95%.

# %%
alpha = 0.05   
power = 0.80     
p = 0.3        
mde = 0.03     
p_target = p + mde  
effect_size = proportion_effectsize(p, p_target)
power_analysis = NormalIndPower()
sample_size = power_analysis.solve_power(
    effect_size=effect_size,
    power=power,
    alpha=alpha,
    ratio=1  
)
print(f"Необходимый размер выборки для каждой группы: {int(sample_size)}")
# Out:
# Необходимый размер выборки для каждой группы: 3761

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Получается данных достаточно. На реальной практике, для ускорения этой проверки обычно все используют онлайн-калькуляторы. Я например использую [этот](https://www.evanmiller.org/ab-testing/sample-size.html)

# %% [markdown]
# - рассчитайте для каждой группы количество посетителей, сделавших покупку, и общее количество посетителей.

# %%
buyers_7days = events_7days[events_7days['event_name'] == 'purchase']['user_id'].unique()
participants_new['purchase'] = participants_new['user_id'].isin(buyers_7days).astype(int)
n_A = len(participants_new[participants_new['group'] == 'A'])
n_B = len(participants_new[participants_new['group'] == 'B'])
m_A = participants_new[(participants_new['group'] == 'A') & (participants_new['purchase'] == 1)].shape[0]
m_B = participants_new[(participants_new['group'] == 'B') & (participants_new['purchase'] == 1)].shape[0]
print(f"Группа A: {n_A} посетителей, {m_A} покупок")
print(f"Группа B: {n_B} посетителей, {m_B} покупок")
# Out:
# Группа A: 5174 посетителей, 1463 покупок
# Группа B: 5229 посетителей, 1574 покупок

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Взяты только уникальные пользователи, молодец

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> на этом этапе будет уместно сразу оченить разницу конверсий, есть ли прирост 2пп. Твои выводы ниже не подтверждены

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Ниже посчитана разница в конверсиях.</div>

# %%
p_A = m_A / n_A 
p_B = m_B / n_B  
diff = p_B - p_A
print(f"\nРазница конверсий составила: {diff*100:.2f} п.п.")
# Out:
# Разница конверсий составила: 1.83 п.п.

# %% [markdown]
# - сделайте предварительный общий вывод об изменении пользовательской активности в тестовой группе по сравнению с контрольной.

# %% [markdown]
# Пользовательская активность (осуществление покупок) в тестовой группе по сравнению с контрольной выросла на 2 процентных пункта в течение 7 дней с момента регистрации.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>

# %% [markdown]
# ## 4. Проведите оценку результатов A/B-тестирования:

# %% [markdown]
# - Проверьте изменение конверсии подходящим статистическим тестом, учитывая все этапы проверки гипотез.

# %% [markdown]
# Пользователи, участвующих в тесте, соответствуют требованиям технического задания, равномерно распределены количественно по группам теста, а также по используемым устройствам, каждый пользователь учтен один раз, между группами нет пересечений.
# Размер необходимой для проверки выборки составляет 3761 человека, что меньше количества пользователей как в группе А, так и в группе В.
# Нулевая гипотеза: Упрощение интерфейса не приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.
# Альтернативная гипотеза: Упрощение интерфейса приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Гипотезы для теста сформулированы

# %% [markdown]
# p_A = m_A / n_A
# p_B = m_B / n_B
# if (p_A * n_A > 10) and ((1 - p_A) * n_A > 10) and (p_B * n_B > 10) and ((1 - p_B) * n_B > 10):
#     print('Предпосылка о достаточном количестве данных выполняется!')
# else:
#     print('Предпосылка о достаточном количестве данных НЕ выполняется!')
# alpha = 0.05
# z_stat, p_value = proportions_ztest(
#     [m_A, m_B],
#     [n_A, n_B],
#     alternative='smaller')
#
# print(f'P-value: {p_value:.6f}')
# if p_value < alpha:
#     print('Нулевая гипотеза находит подтверждение!Упрощение интерфейса не приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.')
# else:
#     print('Нулевая гипотеза не находит подтверждения!Упрощение интерфейса приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.')

# %% [markdown]
# p_A = m_A / n_A
# p_B = m_B / n_B
# if (p_A * n_A > 10) and ((1 - p_A) * n_A > 10) and (p_B * n_B > 10) and ((1 - p_B) * n_B > 10):
#     print('Предпосылка о достаточном количестве данных выполняется!')
# else:
#     print('Предпосылка о достаточном количестве данных НЕ выполняется!')
# alpha = 0.05
# z_stat, p_value = proportions_ztest(
#     [m_B, m_A],
#     [n_B, n_A],
#     alternative='larger'
# )
#
# print(f'P-value: {p_value:.6f}')
#
# if p_value < alpha:
#     print('Нулевая гипотеза не находит подтверждения! Упрощение интерфейса приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.')
# else:
#     print('Нулевая гипотеза находит подтверждение! Упрощение интерфейса не приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>При выбранном направлении тестирования и гипотезах правильнее взять парамерт теста `larger`, это повлияет на результаты

# %%
p_A = m_A / n_A
p_B = m_B / n_B
if (p_A * n_A > 10) and ((1 - p_A) * n_A > 10) and (p_B * n_B > 10) and ((1 - p_B) * n_B > 10):
    print('Предпосылка о достаточном количестве данных выполняется!')
else:
    print('Предпосылка о достаточном количестве данных НЕ выполняется!')
alpha = 0.05 
z_stat, p_value = proportions_ztest(
    [m_B, m_A],          
    [n_B, n_A],          
    alternative='larger'
)

print(f'P-value: {p_value:.6f}')
diff = p_B - p_A  
mde = 0.03        
if p_value < alpha and (diff >= mde):
    print('Нулевая гипотеза не находит подтверждения! Упрощение интерфейса приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.')
else:
    print('Нулевая гипотеза находит подтверждение! Упрощение интерфейса не приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.')
# Out:
# Предпосылка о достаточном количестве данных выполняется!
# P-value: 0.020307
# Нулевая гипотеза находит подтверждение! Упрощение интерфейса не приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Код теста исправлен.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Молодец, что доразобралась в вопросе

# %% [markdown]
# - Опишите выводы по проведённой оценке результатов A/B-тестирования. Что можно сказать про результаты A/B-тестирования? Был ли достигнут ожидаемый эффект в изменении конверсии?

# %% [markdown]
# Упрощение интерфейса не приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации. Ожидаемый эффект в изменении конверсии не достигнут.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Вывод емкий, но потребует актуализации

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Упрощение интерфейса приводит к увеличению конверсии на 3 и более процентных пункта в течение 7 дней после регистрации. Ожидаемый эффект в изменении конверсии достигнут. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Все так, можно смело "раскатывать" новый интерфейс ;)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера**:
#          Спасибо за  проект, качественную отработку моих комментариев и хорошую обратную связь! Ты приложила много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты молодец! У тебя отлично развиты аналитические способности и владение инструментарием.
#
# **Отмечу положительные моменты**:
#
#         1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть.
#
#         2. Понятные и логичные выводы на всех этапах работы.
#
#         3. Лаконичное оформление проекта в целом.
#
#         4. Внимание к деталям в выборе параметров тестов
#
#
#
#
#
#
#
#
# **Алина, поздравляю тебя, еще одна аналитическая работа попадает в твое портфолио. Желаю успешного и интересного продолжения учебы!**
